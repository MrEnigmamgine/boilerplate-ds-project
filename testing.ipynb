# %%
import yaml
import pydataset
import helpers

# %%
with open('config.yaml') as f:
    CFG = yaml.safe_load(f)

if CFG.get('data').get('pydataset'):
    DATA = pydataset.data(CFG.get('data').get('pydataset'))

# %%
df = DATA
df
# Out:
#           class     age    sex survived
# 1     1st class  adults    man      yes
# 2     1st class  adults    man      yes
# 3     1st class  adults    man      yes
# 4     1st class  adults    man      yes
# 5     1st class  adults    man      yes
# ...         ...     ...    ...      ...
# 1312  3rd class   child  women       no
# 1313  3rd class   child  women       no
# 1314  3rd class   child  women       no
# 1315  3rd class   child  women       no
# 1316  3rd class   child  women       no
#
# [1316 rows x 4 columns]

# %%
sql = CFG.get('data').get('sql')
# url = helpers.sql.get_db_url(sql['database'])
helpers.sql.DB = sql['database']
helpers.sql.SQLQUERY = sql['query']
import pandas as pd

df = helpers.sql.get_data()
df.head()
# Out:
#    storytypeid  typeconstructiontypeid  propertylandusetypeid  \
# 0          NaN                     NaN                  261.0
# 1          NaN                     NaN                  261.0
# 2          NaN                     NaN                  261.0
# 3          NaN                     NaN                  261.0
# 4          NaN                     NaN                  261.0
#
#    heatingorsystemtypeid  architecturalstyletypeid  airconditioningtypeid  \
# 0                    NaN                       NaN                    NaN
# 1                    NaN                       NaN                    NaN
# 2                    NaN                       NaN                    NaN
# 3                    2.0                       NaN                    NaN
# 4                    2.0                       NaN                    1.0
#
#    parcelid  id  logerror transactiondate  ...  taxamount  taxdelinquencyflag  \
# ...
